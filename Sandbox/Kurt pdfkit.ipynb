# %%
import pdfkit

# %%
pdfkit.from_url('https://covidtracking.com/blog/florida-covid-19-data', 'covid_tracking.pdf')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pdfkit\configuration.py in __init__(self, wkhtmltopdf, meta_tag_prefix)
#      20         try:
# ---> 21             with open(self.wkhtmltopdf) as f:
#      22                 pass
#
# FileNotFoundError: [Errno 2] No such file or directory: b''
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-d30537ea42df> in <module>
# ----> 1 pdfkit.from_url('https://covidtracking.com/blog/florida-covid-19-data', 'covid_tracking.pdf')
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pdfkit\api.py in from_url(url, output_path, options, toc, cover, configuration, cover_first)
#      22
#      23     r = PDFKit(url, 'url', options=options, toc=toc, cover=cover,
# ...
