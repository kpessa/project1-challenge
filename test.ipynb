# %%
import pandas as pd
import datetime
df = pd.read_csv("Resources/Florida_COVID19_Case_Line_Data.csv")

# %%
df
# Out:
#         ObjectId    County   Age    Age_group  Gender Jurisdiction  \
# 0              1  Pinellas  32.0  25-34 years    Male  FL resident
# 1              2  Pinellas  20.0  15-24 years  Female  FL resident
# 2              3    Citrus  80.0  75-84 years    Male  FL resident
# 3              4   Volusia  66.0  65-74 years  Female  FL resident
# 4              5   Broward  20.0  15-24 years  Female  FL resident
# ...          ...       ...   ...          ...     ...          ...
# 254506    254507    Orange  48.0  45-54 years    Male  FL resident
# 254507    254508    Orange  60.0  55-64 years  Female  FL resident
# 254508    254509   Osceola  34.0  25-34 years  Female  FL resident
# 254509    254510   Volusia  10.0   5-14 years    Male  FL resident
# 254510    254511  Seminole  88.0    85+ years    Male  FL resident
#
#        Travel_related                  Origin  EDvisit Hospitalized Died  \
# 0                  No                     NaN       NO           NO  NaN
# ...

# %%
df = df[["County","Age","Age_group","Gender","Jurisdiction","Hospitalized","EventDate","ChartDate"]]

# %%
df['EventDate'] = pd.to_datetime(df['EventDate'], format="%Y/%m/%d %H:%M:%S")

# %%
df_prior = df[df['EventDate'] < '2020-05-17']
df_after = df[df['EventDate'] >= '2020-05-17']
df_prior
# Out:
#         ObjectId    County   Age    Age_group  Gender     Jurisdiction  \
# 0              1  Pinellas  32.0  25-34 years    Male      FL resident
# 2              3    Citrus  80.0  75-84 years    Male      FL resident
# 3              4   Volusia  66.0  65-74 years  Female      FL resident
# 4              5   Broward  20.0  15-24 years  Female      FL resident
# 5              6   Broward  41.0  35-44 years    Male  Non-FL resident
# ...          ...       ...   ...          ...     ...              ...
# 223152    223153   Collier  37.0  35-44 years    Male      FL resident
# 224319    224320  Pinellas  42.0  35-44 years    Male      FL resident
# 224931    224932     Duval  30.0  25-34 years    Male      FL resident
# 225620    225621  Pinellas  42.0  35-44 years  Female      FL resident
# 242407    242408   Volusia  68.0  65-74 years  Female      FL resident
#
#        Travel_related                  Origin  EDvisit Hospitalized Died  \
# ...

# %%
10000 / df_prior.shape[0]*100
# Out:
# 20.125178610960173

# %%
df_after[df["Hospitalized"]=="YES"]['Hospitalized'].count
# Out:
# C:\Users\kpess\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# <bound method Series.count of 96        YES
# 105       YES
# 157       YES
# 248       YES
# 365       YES
#          ...
# 253907    YES
# 254080    YES
# 254086    YES
# 254496    YES
# 254502    YES
# Name: Hospitalized, Length: 8341, dtype: object>

# %%
8341 / df_after.shape[0]*100
# Out:
# 4.072316450381306
